# %% [markdown]
# ### Data analysis of snow poles images to be passed in a YOLO network

# %% [markdown]
# Installing libraries and importing datasets

# %%
pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 3.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.1 MB 4.1 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.1 MB 5.2 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.1 MB 6.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 6.5 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
